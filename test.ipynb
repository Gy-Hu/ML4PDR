# %%
import os

test_file_path = "./dataset/toy_experiment"
for root, dirs, files in os.walk(test_file_path):
    print(files)
# Out:
# ['test_40.aag', 'abp4.aag', 's1.aag', 's2.aag', 'toy_pipe_arb-start.aig', 'toy_pipe_no-arb-start.aig', 'toy_pipe_arb-start-stall.aig', 'test_35.aag', 'mutual_noproc.aag']

# %%
print("hello")
# Out:
# hello

# %%
# !conda list
# Out:
# # packages in environment at /home/gary/miniconda3/envs/tf2-gpu:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _tflow_select             2.1.0                       gpu
# absl-py                   0.12.0           py39h06a4308_0
# aiohttp                   3.7.4            py39h27cfd23_1
# argon2-cffi               20.1.0           py39h27cfd23_1
# astor                     0.8.1            py39h06a4308_0
# astunparse                1.6.3                      py_0
# async-timeout             3.0.1            py39h06a4308_0
# async_generator           1.10               pyhd3eb1b0_0
# attrs                     21.2.0             pyhd3eb1b0_0
# backcall                  0.2.0              pyhd3eb1b0_0
# blas                      1.0                         mkl
# bleach                    3.3.0              pyhd3eb1b0_0
# blinker                   1.4              py39h06a4308_0
# ...
